# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten,SpatialDropout2D
from keras.layers import Conv2D, MaxPooling2D
from matplotlib import pyplot as plt

# %%
#imagenet or CIFAR
from keras.datasets import cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# separate the train for validation
from sklearn.model_selection import train_test_split
x_train1, x_valid, y_train1, y_valid = train_test_split(x_train, y_train, test_size=0.2)

x_train = x_train1.astype('float32') / 255 
x_valid = x_valid.astype('float32') / 255
x_test = x_test.astype('float32') / 255

from keras.utils.np_utils import to_categorical
N = 10
y_train = to_categorical(y_train1, N)
y_valid = to_categorical(y_valid, N)
y_test = to_categorical(y_test, N)

print(x_train.shape)
print(x_valid.shape)
print(x_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# (40000, 32, 32, 3)
# (10000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
def Model():
  
    model = Sequential()
    
    model.add(Conv2D(64, kernel_size=(5,5), strides = 1, padding='same', activation='relu', input_shape=(32, 32, 3))) # 1st Layer
#     model.add(SpatialDropout2D(rate=0.1))
    model.add(MaxPooling2D(pool_size=(2,2),  strides = 2, padding='same'))
    
    model.add(Conv2D(192, kernel_size=(5,5), strides = 1, padding='same', activation='relu'))       # 2nd Layer
#     model.add(SpatialDropout2D(rate=0.1))
    model.add(MaxPooling2D(pool_size=(2,2),  strides = 2))
    
    model.add(Conv2D(384, kernel_size=(3,3), strides = 1, padding='same', activation='relu'))       # 3rd Layer
#     model.add(SpatialDropout2D(rate=0.1))
    model.add(MaxPooling2D(pool_size=(2,2),  strides = 2))
    
    model.add(Conv2D(256, kernel_size=(5,5), strides = 1, padding='same', activation='relu'))       # 4th Layer
#     model.add(SpatialDropout2D(rate=0.1))
    model.add(MaxPooling2D(pool_size=(2,2),  strides = 2))
    
    model.add(Conv2D(256, kernel_size=(5,5), strides = 1, padding='same', activation='relu'))       # 5th Layer
#     model.add(SpatialDropout2D(rate=0.1))
    model.add(MaxPooling2D(pool_size=(2,2), strides = 2))
    
    model.add(Flatten())
    
    model.add(Dense(4096, activation='relu'))                     # 6th Layer
#     model.add(Dropout(rate=0.5))
    
    model.add(Dense(4096, activation='relu'))                     # 7th Layer
#     model.add(Dropout(rate=0.5))
    
    model.add(Dense(10,activation='softmax'))                     # 8th Layer
    return model


model = Model()

from keras.optimizers import RMSprop
model.compile(loss='categorical_crossentropy',
              # optimizer=RMSprop(learning_rate = 0.001),
              optimizer = 'adam',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        4864
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 192)       307392
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 192)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 384)         663936
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 384)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 256)         2457856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 2, 2, 256)         1638656
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              1052672
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 22,947,658
# Trainable params: 22,947,658
# Non-trainable params: 0
# _________________________________________________________________

# %%
# verbose = setting up the progress bar
history = model.fit(x_train, y_train, batch_size=128, epochs=50, verbose=1, validation_data=(x_valid, y_valid))

# model.save_weights("mnist.hdf5") 
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/50
# 313/313 [==============================] - 16s 30ms/step - loss: 2.0259 - accuracy: 0.1984 - val_loss: 1.4344 - val_accuracy: 0.4555
# Epoch 2/50
# 313/313 [==============================] - 8s 26ms/step - loss: 1.3588 - accuracy: 0.4922 - val_loss: 1.2023 - val_accuracy: 0.5875
# Epoch 3/50
# 313/313 [==============================] - 8s 26ms/step - loss: 1.0533 - accuracy: 0.6219 - val_loss: 1.0302 - val_accuracy: 0.6357
# Epoch 4/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.8543 - accuracy: 0.6979 - val_loss: 0.9762 - val_accuracy: 0.6735
# Epoch 5/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.6901 - accuracy: 0.7597 - val_loss: 0.9272 - val_accuracy: 0.6889
# Epoch 6/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.5476 - accuracy: 0.8120 - val_loss: 0.8930 - val_accuracy: 0.7150
# Epoch 7/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.4437 - accuracy: 0.8467 - val_loss: 0.9163 - val_accuracy: 0.7140
# Epoch 8/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.3096 - accuracy: 0.8964 - val_loss: 0.9937 - val_accuracy: 0.7157
# Epoch 9/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.2463 - accuracy: 0.9163 - val_loss: 1.0869 - val_accuracy: 0.7120
# Epoch 10/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.2142 - accuracy: 0.9263 - val_loss: 1.1848 - val_accuracy: 0.7154
# Epoch 11/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.1569 - accuracy: 0.9474 - val_loss: 1.2682 - val_accuracy: 0.7091
# Epoch 12/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.1468 - accuracy: 0.9507 - val_loss: 1.3327 - val_accuracy: 0.7083
# Epoch 13/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.1172 - accuracy: 0.9602 - val_loss: 1.2571 - val_accuracy: 0.7187
# Epoch 14/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.1042 - accuracy: 0.9646 - val_loss: 1.3245 - val_accuracy: 0.7182
# Epoch 15/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.0836 - accuracy: 0.9724 - val_loss: 1.4702 - val_accuracy: 0.7191
# Epoch 16/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.0915 - accuracy: 0.9689 - val_loss: 1.4955 - val_accuracy: 0.7131
# Epoch 17/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.0820 - accuracy: 0.9718 - val_loss: 1.5326 - val_accuracy: 0.7018
# Epoch 18/50
# Epoch 37/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.0421 - accuracy: 0.9872 - val_loss: 1.9255 - val_accuracy: 0.7079
# Epoch 38/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.0414 - accuracy: 0.9876 - val_loss: 1.9060 - val_accuracy: 0.7147
# Epoch 39/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.0369 - accuracy: 0.9880 - val_loss: 1.9551 - val_accuracy: 0.7109
# Epoch 40/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.0473 - accuracy: 0.9850 - val_loss: 1.8838 - val_accuracy: 0.7009
# Epoch 41/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.0458 - accuracy: 0.9862 - val_loss: 1.9278 - val_accuracy: 0.7057
# Epoch 42/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.0445 - accuracy: 0.9860 - val_loss: 1.7832 - val_accuracy: 0.7018
# Epoch 43/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.0450 - accuracy: 0.9863 - val_loss: 2.2728 - val_accuracy: 0.7149
# Epoch 44/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.0500 - accuracy: 0.9850 - val_loss: 1.8122 - val_accuracy: 0.7085
# Epoch 45/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.0332 - accuracy: 0.9899 - val_loss: 1.8795 - val_accuracy: 0.7123
# Epoch 46/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.0448 - accuracy: 0.9866 - val_loss: 1.8365 - val_accuracy: 0.7209
# Epoch 47/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.0423 - accuracy: 0.9879 - val_loss: 2.2611 - val_accuracy: 0.7156
# Epoch 48/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.0268 - accuracy: 0.9909 - val_loss: 2.0116 - val_accuracy: 0.7156
# Epoch 49/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.0260 - accuracy: 0.9917 - val_loss: 2.3652 - val_accuracy: 0.7070
# Epoch 50/50
# 313/313 [==============================] - 8s 26ms/step - loss: 0.0354 - accuracy: 0.9896 - val_loss: 1.8559 - val_accuracy: 0.7065
# Test loss: 1.9285879135131836
# Test accuracy: 0.7026000022888184

# %%
model.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 1.9286 - accuracy: 0.7026
# [1.9285879135131836, 0.7026000022888184]

# %%
# plot
plt.plot(history.history['accuracy'], marker='.', label='acc')
plt.plot(history.history['val_accuracy'], marker='.', label='val_acc')
plt.title('Model Accuracy')
plt.savefig('task1_accuracy.jpeg')
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='best')
plt.show()

# plot
plt.plot(history.history['loss'], marker='.', label='loss')
plt.plot(history.history['val_loss'], marker='.', label='val_loss')
plt.title('Model Loss')
plt.savefig('task1_loss.jpeg')
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='best')
plt.show()
