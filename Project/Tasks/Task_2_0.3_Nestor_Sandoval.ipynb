# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten,SpatialDropout2D
from keras.layers import Conv2D, MaxPooling2D
from matplotlib import pyplot as plt

# %%
#imagenet or CIFAR
from keras.datasets import cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# separate the train for validation
from sklearn.model_selection import train_test_split
x_train1, x_valid, y_train1, y_valid = train_test_split(x_train, y_train, test_size=0.2)

x_train = x_train1.astype('float32') / 255 
x_valid = x_valid.astype('float32') / 255
x_test = x_test.astype('float32') / 255

from keras.utils.np_utils import to_categorical
N = 10
y_train = to_categorical(y_train1, N)
y_valid = to_categorical(y_valid, N)
y_test = to_categorical(y_test, N)

print(x_train.shape)
print(x_valid.shape)
print(x_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step
# (40000, 32, 32, 3)
# (10000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
def Model():
  
    model = Sequential()
    
    model.add(Conv2D(64, kernel_size=(5,5), strides = 1, padding='same', activation='relu', input_shape=(32, 32, 3))) # 1st Layer
    model.add(SpatialDropout2D(rate=0.3))
    model.add(MaxPooling2D(pool_size=(2,2),  strides = 2, padding='same'))
    
    model.add(Conv2D(192, kernel_size=(5,5), strides = 1, padding='same', activation='relu'))       # 2nd Layer
    model.add(SpatialDropout2D(rate=0.3))
    model.add(MaxPooling2D(pool_size=(2,2),  strides = 2))
    
    model.add(Conv2D(384, kernel_size=(3,3), strides = 1, padding='same', activation='relu'))       # 3rd Layer
    model.add(SpatialDropout2D(rate=0.3))
    model.add(MaxPooling2D(pool_size=(2,2),  strides = 2))
    
    model.add(Conv2D(256, kernel_size=(5,5), strides = 1, padding='same', activation='relu'))       # 4th Layer
    model.add(SpatialDropout2D(rate=0.3))
    model.add(MaxPooling2D(pool_size=(2,2),  strides = 2))
    
    model.add(Conv2D(256, kernel_size=(5,5), strides = 1, padding='same', activation='relu'))       # 5th Layer
    model.add(SpatialDropout2D(rate=0.3))
    model.add(MaxPooling2D(pool_size=(2,2), strides = 2))
    
    model.add(Flatten())
    
    model.add(Dense(4096, activation='relu'))                     # 6th Layer
    model.add(Dropout(rate=0.5))
    
    model.add(Dense(4096, activation='relu'))                     # 7th Layer
    model.add(Dropout(rate=0.5))
    
    model.add(Dense(10,activation='softmax'))                     # 8th Layer
    return model


model = Model()

from keras.optimizers import RMSprop
model.compile(loss='categorical_crossentropy',
              # optimizer=RMSprop(learning_rate = 0.001),
              optimizer = 'adam',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        4864
# _________________________________________________________________
# spatial_dropout2d (SpatialDr (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 192)       307392
# _________________________________________________________________
# spatial_dropout2d_1 (Spatial (None, 16, 16, 192)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 192)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 384)         663936
# _________________________________________________________________
# spatial_dropout2d_2 (Spatial (None, 8, 8, 384)         0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 384)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 256)         2457856
# _________________________________________________________________
# spatial_dropout2d_3 (Spatial (None, 4, 4, 256)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 2, 2, 256)         1638656
# _________________________________________________________________
# spatial_dropout2d_4 (Spatial (None, 2, 2, 256)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              1052672
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 22,947,658
# Trainable params: 22,947,658
# Non-trainable params: 0
# _________________________________________________________________

# %%
# verbose = setting up the progress bar
history = model.fit(x_train, y_train, batch_size=128, epochs=50, verbose=1, validation_data=(x_valid, y_valid))

# model.save_weights("mnist.hdf5") 
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/50
# 313/313 [==============================] - 17s 31ms/step - loss: 2.1229 - accuracy: 0.1703 - val_loss: 1.6698 - val_accuracy: 0.3569
# Epoch 2/50
# 313/313 [==============================] - 9s 28ms/step - loss: 1.7100 - accuracy: 0.3466 - val_loss: 1.4327 - val_accuracy: 0.4617
# Epoch 3/50
# 313/313 [==============================] - 9s 28ms/step - loss: 1.5652 - accuracy: 0.4184 - val_loss: 1.4090 - val_accuracy: 0.4720
# Epoch 4/50
# 313/313 [==============================] - 9s 28ms/step - loss: 1.4678 - accuracy: 0.4665 - val_loss: 1.2550 - val_accuracy: 0.5440
# Epoch 5/50
# 313/313 [==============================] - 9s 28ms/step - loss: 1.3881 - accuracy: 0.4962 - val_loss: 1.1838 - val_accuracy: 0.5785
# Epoch 6/50
# 313/313 [==============================] - 9s 28ms/step - loss: 1.3266 - accuracy: 0.5247 - val_loss: 1.1453 - val_accuracy: 0.5911
# Epoch 7/50
# 313/313 [==============================] - 9s 28ms/step - loss: 1.3014 - accuracy: 0.5360 - val_loss: 1.0803 - val_accuracy: 0.6210
# Epoch 8/50
# 313/313 [==============================] - 9s 28ms/step - loss: 1.2481 - accuracy: 0.5593 - val_loss: 1.0789 - val_accuracy: 0.6228
# Epoch 9/50
# 313/313 [==============================] - 9s 28ms/step - loss: 1.2180 - accuracy: 0.5696 - val_loss: 1.1007 - val_accuracy: 0.6091
# Epoch 10/50
# 313/313 [==============================] - 9s 28ms/step - loss: 1.1879 - accuracy: 0.5830 - val_loss: 1.0335 - val_accuracy: 0.6384
# Epoch 11/50
# 313/313 [==============================] - 9s 28ms/step - loss: 1.1594 - accuracy: 0.5960 - val_loss: 0.9799 - val_accuracy: 0.6549
# Epoch 12/50
# 313/313 [==============================] - 9s 28ms/step - loss: 1.1381 - accuracy: 0.6045 - val_loss: 0.9815 - val_accuracy: 0.6663
# Epoch 13/50
# 313/313 [==============================] - 9s 28ms/step - loss: 1.1335 - accuracy: 0.6052 - val_loss: 0.9622 - val_accuracy: 0.6648
# Epoch 14/50
# 313/313 [==============================] - 9s 28ms/step - loss: 1.0880 - accuracy: 0.6236 - val_loss: 0.9648 - val_accuracy: 0.6641
# Epoch 15/50
# 313/313 [==============================] - 9s 28ms/step - loss: 1.0897 - accuracy: 0.6230 - val_loss: 0.9518 - val_accuracy: 0.6722
# Epoch 16/50
# 313/313 [==============================] - 9s 28ms/step - loss: 1.0677 - accuracy: 0.6363 - val_loss: 0.8948 - val_accuracy: 0.6947
# 313/313 [==============================] - 9s 28ms/step - loss: 0.8842 - accuracy: 0.7064 - val_loss: 0.8263 - val_accuracy: 0.7210
# Epoch 37/50
# 313/313 [==============================] - 9s 28ms/step - loss: 0.8769 - accuracy: 0.7094 - val_loss: 0.7861 - val_accuracy: 0.7358
# Epoch 38/50
# 313/313 [==============================] - 9s 28ms/step - loss: 0.8717 - accuracy: 0.7106 - val_loss: 0.8121 - val_accuracy: 0.7291
# Epoch 39/50
# 313/313 [==============================] - 9s 28ms/step - loss: 0.8515 - accuracy: 0.7164 - val_loss: 0.7739 - val_accuracy: 0.7404
# Epoch 40/50
# 313/313 [==============================] - 9s 28ms/step - loss: 0.8235 - accuracy: 0.7267 - val_loss: 0.7976 - val_accuracy: 0.7369
# Epoch 41/50
# 313/313 [==============================] - 9s 28ms/step - loss: 0.8649 - accuracy: 0.7164 - val_loss: 0.7842 - val_accuracy: 0.7389
# Epoch 42/50
# 313/313 [==============================] - 9s 28ms/step - loss: 0.8303 - accuracy: 0.7264 - val_loss: 0.8002 - val_accuracy: 0.7321
# Epoch 43/50
# 313/313 [==============================] - 9s 28ms/step - loss: 0.8455 - accuracy: 0.7208 - val_loss: 0.7780 - val_accuracy: 0.7455
# Epoch 44/50
# 313/313 [==============================] - 9s 28ms/step - loss: 0.8329 - accuracy: 0.7235 - val_loss: 0.7931 - val_accuracy: 0.7362
# Epoch 45/50
# 313/313 [==============================] - 9s 28ms/step - loss: 0.8398 - accuracy: 0.7237 - val_loss: 0.8188 - val_accuracy: 0.7253
# Epoch 46/50
# 313/313 [==============================] - 9s 28ms/step - loss: 0.8350 - accuracy: 0.7237 - val_loss: 0.7885 - val_accuracy: 0.7440
# Epoch 47/50
# 313/313 [==============================] - 9s 28ms/step - loss: 0.8325 - accuracy: 0.7274 - val_loss: 0.7991 - val_accuracy: 0.7378
# Epoch 48/50
# 313/313 [==============================] - 9s 28ms/step - loss: 0.8477 - accuracy: 0.7215 - val_loss: 0.7792 - val_accuracy: 0.7455
# Epoch 49/50
# 313/313 [==============================] - 9s 28ms/step - loss: 0.8234 - accuracy: 0.7303 - val_loss: 0.7671 - val_accuracy: 0.7432
# Epoch 50/50
# 313/313 [==============================] - 9s 28ms/step - loss: 0.8202 - accuracy: 0.7326 - val_loss: 0.7601 - val_accuracy: 0.7508
# Test loss: 0.7693658471107483
# Test accuracy: 0.7486000061035156

# %%
model.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.7694 - accuracy: 0.7486
# [0.7693658471107483, 0.7486000061035156]

# %%
# plot
plt.plot(history.history['accuracy'], marker='.', label='acc')
plt.plot(history.history['val_accuracy'], marker='.', label='val_acc')
plt.title('Model Accuracy')
plt.savefig('task2_accuracy.jpeg')
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='best')
plt.show()

# plot
plt.plot(history.history['loss'], marker='.', label='loss')
plt.plot(history.history['val_loss'], marker='.', label='val_loss')
plt.title('Model Loss')
plt.savefig('task2_loss.jpeg')
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='best')
plt.show()
