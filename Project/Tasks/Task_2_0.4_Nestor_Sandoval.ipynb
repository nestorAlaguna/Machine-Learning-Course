# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten,SpatialDropout2D
from keras.layers import Conv2D, MaxPooling2D
from matplotlib import pyplot as plt

# %%
#imagenet or CIFAR
from keras.datasets import cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# separate the train for validation
from sklearn.model_selection import train_test_split
x_train1, x_valid, y_train1, y_valid = train_test_split(x_train, y_train, test_size=0.2)

x_train = x_train1.astype('float32') / 255 
x_valid = x_valid.astype('float32') / 255
x_test = x_test.astype('float32') / 255

from keras.utils.np_utils import to_categorical
N = 10
y_train = to_categorical(y_train1, N)
y_valid = to_categorical(y_valid, N)
y_test = to_categorical(y_test, N)

print(x_train.shape)
print(x_valid.shape)
print(x_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step
# (40000, 32, 32, 3)
# (10000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
def Model():
  
    model = Sequential()
    
    model.add(Conv2D(64, kernel_size=(5,5), strides = 1, padding='same', activation='relu', input_shape=(32, 32, 3))) # 1st Layer
    model.add(SpatialDropout2D(rate=0.4))
    model.add(MaxPooling2D(pool_size=(2,2),  strides = 2, padding='same'))
    
    model.add(Conv2D(192, kernel_size=(5,5), strides = 1, padding='same', activation='relu'))       # 2nd Layer
    model.add(SpatialDropout2D(rate=0.4))
    model.add(MaxPooling2D(pool_size=(2,2),  strides = 2))
    
    model.add(Conv2D(384, kernel_size=(3,3), strides = 1, padding='same', activation='relu'))       # 3rd Layer
    model.add(SpatialDropout2D(rate=0.4))
    model.add(MaxPooling2D(pool_size=(2,2),  strides = 2))
    
    model.add(Conv2D(256, kernel_size=(5,5), strides = 1, padding='same', activation='relu'))       # 4th Layer
    model.add(SpatialDropout2D(rate=0.4))
    model.add(MaxPooling2D(pool_size=(2,2),  strides = 2))
    
    model.add(Conv2D(256, kernel_size=(5,5), strides = 1, padding='same', activation='relu'))       # 5th Layer
    model.add(SpatialDropout2D(rate=0.4))
    model.add(MaxPooling2D(pool_size=(2,2), strides = 2))
    
    model.add(Flatten())
    
    model.add(Dense(4096, activation='relu'))                     # 6th Layer
    model.add(Dropout(rate=0.5))
    
    model.add(Dense(4096, activation='relu'))                     # 7th Layer
    model.add(Dropout(rate=0.5))
    
    model.add(Dense(10,activation='softmax'))                     # 8th Layer
    return model


model = Model()

from keras.optimizers import RMSprop
model.compile(loss='categorical_crossentropy',
              # optimizer=RMSprop(learning_rate = 0.001),
              optimizer = 'adam',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        4864
# _________________________________________________________________
# spatial_dropout2d (SpatialDr (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 192)       307392
# _________________________________________________________________
# spatial_dropout2d_1 (Spatial (None, 16, 16, 192)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 192)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 384)         663936
# _________________________________________________________________
# spatial_dropout2d_2 (Spatial (None, 8, 8, 384)         0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 384)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 256)         2457856
# _________________________________________________________________
# spatial_dropout2d_3 (Spatial (None, 4, 4, 256)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 2, 2, 256)         1638656
# _________________________________________________________________
# spatial_dropout2d_4 (Spatial (None, 2, 2, 256)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              1052672
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 22,947,658
# Trainable params: 22,947,658
# Non-trainable params: 0
# _________________________________________________________________

# %%
# verbose = setting up the progress bar
history = model.fit(x_train, y_train, batch_size=128, epochs=50, verbose=1, validation_data=(x_valid, y_valid))

# model.save_weights("mnist.hdf5") 
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/50
# 313/313 [==============================] - 18s 34ms/step - loss: 2.2996 - accuracy: 0.1016 - val_loss: 2.1403 - val_accuracy: 0.1806
# Epoch 2/50
# 313/313 [==============================] - 9s 29ms/step - loss: 2.0833 - accuracy: 0.2016 - val_loss: 1.8259 - val_accuracy: 0.3170
# Epoch 3/50
# 313/313 [==============================] - 9s 29ms/step - loss: 1.8929 - accuracy: 0.2785 - val_loss: 1.7188 - val_accuracy: 0.3710
# Epoch 4/50
# 313/313 [==============================] - 9s 29ms/step - loss: 1.8046 - accuracy: 0.3183 - val_loss: 1.7228 - val_accuracy: 0.3657
# Epoch 5/50
# 313/313 [==============================] - 9s 30ms/step - loss: 1.7331 - accuracy: 0.3548 - val_loss: 1.5612 - val_accuracy: 0.4399
# Epoch 6/50
# 313/313 [==============================] - 9s 29ms/step - loss: 1.7016 - accuracy: 0.3695 - val_loss: 1.6031 - val_accuracy: 0.4200
# Epoch 7/50
# 313/313 [==============================] - 9s 29ms/step - loss: 1.6548 - accuracy: 0.3905 - val_loss: 1.5539 - val_accuracy: 0.4451
# Epoch 8/50
# 313/313 [==============================] - 9s 29ms/step - loss: 1.6437 - accuracy: 0.3981 - val_loss: 1.5247 - val_accuracy: 0.4512
# Epoch 9/50
# 313/313 [==============================] - 9s 29ms/step - loss: 1.6028 - accuracy: 0.4094 - val_loss: 1.4653 - val_accuracy: 0.4786
# Epoch 10/50
# 313/313 [==============================] - 9s 30ms/step - loss: 1.5557 - accuracy: 0.4327 - val_loss: 1.4548 - val_accuracy: 0.4868
# Epoch 11/50
# 313/313 [==============================] - 9s 29ms/step - loss: 1.5444 - accuracy: 0.4416 - val_loss: 1.3441 - val_accuracy: 0.5260
# Epoch 12/50
# 313/313 [==============================] - 9s 30ms/step - loss: 1.5140 - accuracy: 0.4543 - val_loss: 1.3740 - val_accuracy: 0.5104
# Epoch 13/50
# 313/313 [==============================] - 9s 29ms/step - loss: 1.4980 - accuracy: 0.4587 - val_loss: 1.3931 - val_accuracy: 0.5072
# Epoch 14/50
# 313/313 [==============================] - 9s 30ms/step - loss: 1.4857 - accuracy: 0.4672 - val_loss: 1.3296 - val_accuracy: 0.5254
# Epoch 15/50
# 313/313 [==============================] - 9s 29ms/step - loss: 1.4668 - accuracy: 0.4766 - val_loss: 1.3121 - val_accuracy: 0.5291
# Epoch 16/50
# 313/313 [==============================] - 9s 30ms/step - loss: 1.4586 - accuracy: 0.4804 - val_loss: 1.2896 - val_accuracy: 0.5333
# 313/313 [==============================] - 9s 29ms/step - loss: 1.3024 - accuracy: 0.5451 - val_loss: 1.1949 - val_accuracy: 0.6001
# Epoch 37/50
# 313/313 [==============================] - 9s 30ms/step - loss: 1.2884 - accuracy: 0.5537 - val_loss: 1.2131 - val_accuracy: 0.5970
# Epoch 38/50
# 313/313 [==============================] - 9s 29ms/step - loss: 1.2761 - accuracy: 0.5567 - val_loss: 1.1048 - val_accuracy: 0.6208
# Epoch 39/50
# 313/313 [==============================] - 9s 29ms/step - loss: 1.2558 - accuracy: 0.5664 - val_loss: 1.1177 - val_accuracy: 0.6314
# Epoch 40/50
# 313/313 [==============================] - 9s 29ms/step - loss: 1.2872 - accuracy: 0.5544 - val_loss: 1.1427 - val_accuracy: 0.6209
# Epoch 41/50
# 313/313 [==============================] - 9s 29ms/step - loss: 1.2578 - accuracy: 0.5648 - val_loss: 1.1251 - val_accuracy: 0.6212
# Epoch 42/50
# 313/313 [==============================] - 9s 29ms/step - loss: 1.2481 - accuracy: 0.5750 - val_loss: 1.1246 - val_accuracy: 0.6280
# Epoch 43/50
# 313/313 [==============================] - 9s 29ms/step - loss: 1.2679 - accuracy: 0.5680 - val_loss: 1.1079 - val_accuracy: 0.6381
# Epoch 44/50
# 313/313 [==============================] - 9s 30ms/step - loss: 1.2430 - accuracy: 0.5708 - val_loss: 1.1196 - val_accuracy: 0.6358
# Epoch 45/50
# 313/313 [==============================] - 9s 29ms/step - loss: 1.2678 - accuracy: 0.5671 - val_loss: 1.1254 - val_accuracy: 0.6358
# Epoch 46/50
# 313/313 [==============================] - 9s 29ms/step - loss: 1.2620 - accuracy: 0.5680 - val_loss: 1.1156 - val_accuracy: 0.6335
# Epoch 47/50
# 313/313 [==============================] - 9s 29ms/step - loss: 1.2312 - accuracy: 0.5770 - val_loss: 1.1272 - val_accuracy: 0.6209
# Epoch 48/50
# 313/313 [==============================] - 9s 30ms/step - loss: 1.2526 - accuracy: 0.5660 - val_loss: 1.1198 - val_accuracy: 0.6259
# Epoch 49/50
# 313/313 [==============================] - 9s 29ms/step - loss: 1.2440 - accuracy: 0.5740 - val_loss: 1.1016 - val_accuracy: 0.6376
# Epoch 50/50
# 313/313 [==============================] - 9s 29ms/step - loss: 1.2387 - accuracy: 0.5758 - val_loss: 1.1545 - val_accuracy: 0.6257
# Test loss: 1.1509456634521484
# Test accuracy: 0.6262000203132629

# %%
model.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 1.1509 - accuracy: 0.6262
# [1.1509456634521484, 0.6262000203132629]

# %%
# plot
plt.plot(history.history['accuracy'], marker='.', label='acc')
plt.plot(history.history['val_accuracy'], marker='.', label='val_acc')
plt.title('Model Accuracy')
plt.savefig('task2_accuracy.jpeg')
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='best')
plt.show()

# plot
plt.plot(history.history['loss'], marker='.', label='loss')
plt.plot(history.history['val_loss'], marker='.', label='val_loss')
plt.title('Model Loss')
plt.savefig('task2_loss.jpeg')
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='best')
plt.savefig('task2_loss.jpeg')
plt.show()
